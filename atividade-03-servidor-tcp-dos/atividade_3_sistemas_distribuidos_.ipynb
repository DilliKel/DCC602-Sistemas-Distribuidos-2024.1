# %%
# Kelvin Araújo Ferreira - 2019037653
# Mateus Moraes de Moura - 2019027100

# %%
import socket
import threading

# Função para lidar com a conexão do cliente
def handle_client(conn, addr):
    print(f"[NOVA CONEXÃO] {addr} conectado.")

    connected = True
    while connected:
        msg = conn.recv(1024).decode()
        if msg:
            if msg.lower() == "quit":
                connected = False
            else:
                reversed_msg = msg[::-1]
                conn.sendall(reversed_msg.encode())
                print(f"[{addr}] Mensagem original: {msg} | Mensagem invertida: {reversed_msg}")

    conn.close()
    print(f"[DESCONECTADO] {addr} desconectado.")

# Função para iniciar o servidor
def start_server():
    host = "localhost"
    port = 12345

    server = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    server.bind((host, port))
    server.listen()
    print(f"[ESPERANDO CONEXÕES] Servidor está ouvindo em {host}:{port}.")

    while True:
        conn, addr = server.accept()
        thread = threading.Thread(target=handle_client, args=(conn, addr))
        thread.start()
        print(f"[CONEXÕES ATIVAS] {threading.activeCount() - 1}")

# Iniciando o servidor em uma thread separada para não bloquear o notebook
server_thread = threading.Thread(target=start_server, daemon=True)
server_thread.start()
# Out:
# Exception in thread Thread-1932 (start_server):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-6-180bb64c6f94>", line 28, in start_server
# OSError: [Errno 98] Address already in use

# %%
import socket
import threading

# Função para enviar mensagem ao servidor
def send_message(msg, host="localhost", port=12345):
    client = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    client.connect((host, port))
    client.sendall(msg.encode())
    response = client.recv(1024).decode()
    print(f"Mensagem enviada: {msg} | Resposta do servidor: {response}")
    client.close()

# Função para iniciar o cliente
def start_client():
    host = "localhost"
    port = 12345

    while True:
        msg = input("Digite a mensagem a ser enviada (ou 'quit' para sair): ")
        if msg.lower() == "quit":
            break
        thread = threading.Thread(target=send_message, args=(msg, host, port))
        thread.start()

# Iniciar o cliente em uma thread separada
client_thread = threading.Thread(target=start_client)
client_thread.start()
# Out:
# Digite a mensagem a ser enviada (ou 'quit' para sair): oie

# %%
import time
import psutil
import matplotlib.pyplot as plt

# Função para simular um ataque DoS enviando múltiplas requisições
def mass_request_test(num_requests, message_size):
    host = "localhost"
    port = 12345
    message = "x" * message_size  # Mensagem de tamanho específico

    threads = []
    for _ in range(num_requests):
        thread = threading.Thread(target=send_message, args=(message, host, port))
        threads.append(thread)
        thread.start()

    for thread in threads:
        thread.join()

# Função para monitorar o uso de recursos
def monitor_performance(duration=10):
    cpu_usage = []
    memory_usage = []
    network_usage = []

    for _ in range(duration):
        cpu_usage.append(psutil.cpu_percent(interval=1))
        memory_usage.append(psutil.virtual_memory().percent)
        network_usage.append(psutil.net_io_counters().bytes_sent + psutil.net_io_counters().bytes_recv)

    return cpu_usage, memory_usage, network_usage

# Iniciar o monitoramento de desempenho
cpu_usage, memory_usage, network_usage = monitor_performance(duration=30)

# Simular um teste de 1000 requisições com mensagens de 512 bytes
mass_request_test(num_requests=1000, message_size=512)

# Plotar os resultados
plt.figure(figsize=(12, 6))

plt.subplot(3, 1, 1)
plt.plot(cpu_usage, label='CPU Usage (%)')
plt.legend()

plt.subplot(3, 1, 2)
plt.plot(memory_usage, label='Memory Usage (%)')
plt.legend()

plt.subplot(3, 1, 3)
plt.plot(network_usage, label='Network Usage (Bytes)')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-2-180bb64c6f94>:36: DeprecationWarning: activeCount() is deprecated, use active_count() instead
#   print(f"[CONEXÕES ATIVAS] {threading.activeCount() - 1}")
# [NOVA CONEXÃO] ('127.0.0.1', 59774) conectado.[CONEXÕES ATIVAS] 927
#
# Mensagem enviada: oie | Resposta do servidor: eio
# [('127.0.0.1', 59774)] Mensagem original: oie | Mensagem invertida: eio
# [NOVA CONEXÃO] ('127.0.0.1', 39842) conectado.[CONEXÕES ATIVAS] 928
#
# [('127.0.0.1', 39842)] Mensagem original: Salve | Mensagem invertida: evlaS
# Mensagem enviada: Salve | Resposta do servidor: evlaS
# [NOVA CONEXÃO] ('127.0.0.1', 38178) conectado.
# Mensagem enviada: eiO | Resposta do servidor: Oie[CONEXÕES ATIVAS] 929
#
# [('127.0.0.1', 38178)] Mensagem original: eiO | Mensagem invertida: Oie
# [NOVA CONEXÃO] ('127.0.0.1', 51638) conectado.[CONEXÕES ATIVAS] 930
#
# [('127.0.0.1', 51638)] Mensagem original: ararA | Mensagem invertida: AraraMensagem enviada: ararA | Resposta do servidor: Arara
#
# ...

# %% [markdown]
# # Projeto Final
#
# **Tema do Trabalho:** Desenvolvimento de um Chatbot para Check-in de Hotel Contêinerizado com Docker
#
# # Objetivo:
#
# Desenvolver um chatbot que auxilie os hóspedes no processo de check-in de um hotel, permitindo que eles realizem o registro de forma automatizada e interativa. O chatbot será implementado utilizando multithreading para gerenciar múltiplas conversas simultâneas e será contêinerizado usando Docker.
#
# # Descrição do Projeto:
#
# O projeto consiste em criar um chatbot que simula o processo de check-in de um hotel. O chatbot irá coletar informações básicas do hóspede, como nome, número da reserva e horário de chegada, e fornecerá as instruções necessárias para o check-in. O sistema deve ser capaz de atender vários hóspedes ao mesmo tempo, utilizando threads para gerenciar cada conversa separadamente. O chatbot será contêinerizado utilizando Docker, facilitando a implantação em diferentes ambientes.
#
# ---
# # Componentes do Trabalho
#
# # Chatbot para Check-in:
#
# - Implementação de um chatbot em Python que interage com os hóspedes, coletando as informações necessárias para o check-in.
# - Uso de multithreading para permitir que o chatbot gerencie várias sessões de check-in simultâneas.
#
#
# # Dockerização:
#
# - Criação de um Dockerfile para contêinerizar o chatbot.
# - Uso de Docker Compose (opcional) para orquestrar o chatbot junto a outros serviços necessários, como um banco de dados simples para armazenar informações de reserva.
#
# # Teste de Desempenho:
#
# - Testar o chatbot para avaliar como ele lida com múltiplas interações simultâneas durante o processo de check-in.
# - Medir o tempo de resposta e a capacidade do chatbot de gerenciar múltiplas conversas ao mesmo tempo.
#
# # Relatório:
#
# - Introdução aos conceitos de chatbots, multithreading, contêineres e o processo de check-in automatizado.
# - Descrição técnica da implementação do chatbot.
# - Resultados dos testes de desempenho, com gráficos simples de tempos de resposta e uso de recursos.
# - Conclusão sobre a eficácia do chatbot em um ambiente contêinerizado e possíveis melhorias futuras.
#
# #  Ferramentas Sugeridas
# - Python: Para implementar o chatbot usando bibliotecas como Flask para a interface web e threading para multithreading.
# - Docker: Para criar e rodar o contêiner do chatbot.
# - Docker Compose: (Opcional) Para facilitar a configuração de ambientes mais complexos com banco de dados.
# - SQLite ou MySQL: Para armazenar as informações de reserva e check-in.
# - Apache JMeter: Para realizar testes de carga no chatbot.
#
#
# # Passos para Desenvolvimento
# 1. Implementar o chatbot básico que coleta informações do hóspede e simula o check-in.
# 2. Adicionar multithreading para suportar múltiplos hóspedes simultâneos.
# 3. Criar um Dockerfile para contêinerizar o chatbot e configurar o ambiente com Docker Compose, se necessário.
# 4. Testar o desempenho do chatbot em cenários com múltiplos hóspedes realizando check-in ao mesmo tempo.
# 5. Documentar o processo e os resultados em um relatório.
